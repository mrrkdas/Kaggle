# %% [markdown]
# # Load in the dataset and clean

# %%
import tensorflow as tf
import sklearn
import pandas as pd
import numpy as np

# %%
# We will use the binary columns for this test
X_cols =['B_30', 'B_38', 'D_114', 'D_116', 'D_117', 'D_120', 'D_126', 'D_63', 'D_64', 'D_66', 'D_68']

# %%
chunksize = 1000000

train_df_iter = pd.read_csv("train_data.csv", chunksize=chunksize, usecols=["customer_ID"] + X_cols)


train_df = pd.DataFrame()
for i_chunk, chunk in enumerate(train_df_iter):
    train_df = pd.concat([train_df, chunk])
    print(train_df.shape)
# Out:
# (1000000, 12)
# (2000000, 12)
# (3000000, 12)
# (4000000, 12)
# (5000000, 12)
# (5531451, 12)

# %%
train_labels_df = pd.read_csv("train_labels.csv")

# %% [markdown]
# ## We will Label encode every multi-class variable in the dataset

# %%
train_df.loc[500000:]
# Out:
#                                                customer_ID D_63 D_64  D_66  \
# 500000   174c5845a69b53beac167eed7b6cad7dc4856a71b4e727...   CR    O   1.0
# 500001   174c5845a69b53beac167eed7b6cad7dc4856a71b4e727...   CR    O   1.0
# 500002   174c5845a69b53beac167eed7b6cad7dc4856a71b4e727...   CR    O   1.0
# 500003   174c5845a69b53beac167eed7b6cad7dc4856a71b4e727...   CR    O   1.0
# 500004   174c5845a69b53beac167eed7b6cad7dc4856a71b4e727...   CR    U   1.0
# ...                                                    ...  ...  ...   ...
# 5531446  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea...   CL    O   NaN
# 5531447  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea...   CL    O   NaN
# 5531448  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea...   CL    O   NaN
# 5531449  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea...   CL    O   NaN
# 5531450  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea...   CL    O   NaN
#
#          D_68  B_30  B_38  D_114  D_116  D_117  D_120  D_126
# 500000    6.0   0.0   5.0    1.0    0.0   -1.0    0.0    1.0
# 500001    6.0   0.0   2.0    1.0    0.0   -1.0    0.0    1.0
# 500002    6.0   0.0   3.0    1.0    0.0   -1.0    0.0    1.0
# 500003    6.0   0.0   3.0    1.0    0.0   -1.0    0.0    1.0
# 500004    4.0   0.0   3.0    1.0    0.0    6.0    0.0    1.0
# ...       ...   ...   ...    ...    ...    ...    ...    ...
# 5531446   5.0   0.0   3.0    1.0    0.0    3.0    0.0    1.0
# 5531447   5.0   0.0   3.0    1.0    0.0    3.0    0.0    1.0
# 5531448   5.0   0.0   3.0    1.0    0.0    3.0    0.0    1.0
# 5531449   5.0   0.0   3.0    1.0    0.0    3.0    0.0    1.0
# 5531450   5.0   0.0   3.0    1.0    0.0    3.0    0.0    1.0
#
# [5031451 rows x 12 columns]

# %%
def replace_all_nan_in_train_df(train_df):
    train_df["D_66"].fillna(1, inplace = True)
    train_df["D_116"].fillna(0, inplace = True)
    train_df["D_64"].fillna("U", inplace = True)
    train_df["D_68"].fillna(4, inplace = True)
    train_df["B_30"].fillna(1, inplace = True)
    train_df["B_38"].fillna(4, inplace = True)
    train_df["D_114"].fillna(0, inplace = True)
    train_df["D_117"].fillna(6, inplace = True)
    train_df["D_120"].fillna(1, inplace = True)
    train_df["D_126"].fillna(0, inplace = True)

# %%
train_df["D_116"].isna().sum()
# Out:
# 0

# %%
replace_all_nan_in_train_df(train_df)

# %%
train_df.isna().sum()
# Out:
# customer_ID    0
# D_63           0
# D_64           0
# D_66           0
# D_68           0
# B_30           0
# B_38           0
# D_114          0
# D_116          0
# D_117          0
# D_120          0
# D_126          0
# dtype: int64

# %%
train_df = pd.merge(train_df, train_labels_df, on="customer_ID", how="left")

# %%
# Label encoder
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
D_63 = le.fit_transform(train_df["D_63"])

# %%
train_df["D_63"] = D_63

# %%
train_df.head()
# Out:
#                                          customer_ID  D_63 D_64  D_66  D_68  \
# 0  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...     2    O   1.0   6.0
# 1  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...     2    O   1.0   6.0
# 2  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...     2    O   1.0   6.0
# 3  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...     2    O   1.0   6.0
# 4  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...     2    O   1.0   6.0
#
#    B_30  B_38  D_114  D_116  D_117  D_120  D_126  target
# 0   0.0   2.0    1.0    0.0    4.0    0.0    1.0       0
# 1   0.0   2.0    1.0    0.0    4.0    0.0    1.0       0
# 2   0.0   2.0    1.0    0.0    4.0    0.0    1.0       0
# 3   0.0   2.0    1.0    0.0    4.0    0.0    1.0       0
# 4   0.0   2.0    1.0    0.0    4.0    0.0    1.0       0

# %%
D_64 = le.fit_transform(train_df["D_64"])
train_df["D_64"] = D_64

# %%
train_df.head()
# Out:
#                                          customer_ID  D_63  D_64  D_66  D_68  \
# 0  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...     2     1   1.0   6.0
# 1  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...     2     1   1.0   6.0
# 2  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...     2     1   1.0   6.0
# 3  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...     2     1   1.0   6.0
# 4  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...     2     1   1.0   6.0
#
#    B_30  B_38  D_114  D_116  D_117  D_120  D_126  target
# 0   0.0   2.0    1.0    0.0    4.0    0.0    1.0       0
# 1   0.0   2.0    1.0    0.0    4.0    0.0    1.0       0
# 2   0.0   2.0    1.0    0.0    4.0    0.0    1.0       0
# 3   0.0   2.0    1.0    0.0    4.0    0.0    1.0       0
# 4   0.0   2.0    1.0    0.0    4.0    0.0    1.0       0

# %%
train_df.columns
# Out:
# Index(['customer_ID', 'D_63', 'D_64', 'D_66', 'D_68', 'B_30', 'B_38', 'D_114',
#        'D_116', 'D_117', 'D_120', 'D_126', 'target'],
#       dtype='object')

# %%
# re-organizing the columns
train_df = train_df[['customer_ID', 'D_63', 'D_64', 'D_66', 'D_68', 'B_30', 'B_38', 'D_114', 'D_116', 'D_117', 'D_120',
       'D_126', 'target']]

# %%
train_df
# Out:
#                                                customer_ID  D_63  D_64  D_66  \
# 0        0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...     2     1   1.0
# 1        0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...     2     1   1.0
# 2        0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...     2     1   1.0
# 3        0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...     2     1   1.0
# 4        0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...     2     1   1.0
# ...                                                    ...   ...   ...   ...
# 5531446  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea...     0     1   1.0
# 5531447  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea...     0     1   1.0
# 5531448  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea...     0     1   1.0
# 5531449  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea...     0     1   1.0
# 5531450  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea...     0     1   1.0
#
#          D_68  B_30  B_38  D_114  D_116  D_117  D_120  D_126  target
# 0         6.0   0.0   2.0    1.0    0.0    4.0    0.0    1.0       0
# 1         6.0   0.0   2.0    1.0    0.0    4.0    0.0    1.0       0
# 2         6.0   0.0   2.0    1.0    0.0    4.0    0.0    1.0       0
# 3         6.0   0.0   2.0    1.0    0.0    4.0    0.0    1.0       0
# 4         6.0   0.0   2.0    1.0    0.0    4.0    0.0    1.0       0
# ...       ...   ...   ...    ...    ...    ...    ...    ...     ...
# 5531446   5.0   0.0   3.0    1.0    0.0    3.0    0.0    1.0       0
# 5531447   5.0   0.0   3.0    1.0    0.0    3.0    0.0    1.0       0
# 5531448   5.0   0.0   3.0    1.0    0.0    3.0    0.0    1.0       0
# 5531449   5.0   0.0   3.0    1.0    0.0    3.0    0.0    1.0       0
# 5531450   5.0   0.0   3.0    1.0    0.0    3.0    0.0    1.0       0
#
# [5531451 rows x 13 columns]

# %%
_X_cols_ = train_df.columns[1:-1]

# %%
_X_cols = train_df.columns[1:-1]

# %% [markdown]
# ## Now we will train_test_split and create a model

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(train_df[_X_cols_], train_df["target"], 
                                                    random_state=42, stratify=train_df["target"])

# %%
X_train.shape
# Out:
# (4148588, 11)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(164, activation = "relu"),
    tf.keras.layers.Dense(128, activation = "relu"),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(64, activation = "relu"),
    tf.keras.layers.Dense(32, activation = "relu"),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(8, activation = "relu"),
    tf.keras.layers.Dense(1, activation = "sigmoid")
])

# %%
model.compile(loss = "binary_crossentropy", optimizer = "adam", metrics = "accuracy")

# %%
model.fit(X_train, y_train, epochs = 3)
# Out:
# Epoch 1/3
# 129644/129644 [==============================] - 181s 1ms/step - loss: 0.4084 - accuracy: 0.8028
# Epoch 2/3
# 129644/129644 [==============================] - 180s 1ms/step - loss: 0.4057 - accuracy: 0.8043
# Epoch 3/3
# 129644/129644 [==============================] - 178s 1ms/step - loss: 0.4052 - accuracy: 0.8048

# %%
model.evaluate(X_test, y_test)
# Out:
# 43215/43215 [==============================] - 48s 1ms/step - loss: 0.4321 - accuracy: 0.8047
# [0.43211281299591064, 0.8047152757644653]

# %%
chunksize = 1000000

test_df_iter = pd.read_csv("test_data.csv", chunksize=chunksize, usecols=["customer_ID"] + X_cols)

# %%
_index = []
_vals = []

for chunk in test_df_iter:
    # Reseting index to have 924621
    _chunk_last = chunk.groupby("customer_ID")[X_cols].last().reset_index() 
    _chunk = _chunk_last


    X_test = _chunk[_X_cols_]
    
    # Getting rid of NaN
    X_test["D_66"].fillna(1, inplace = True)
    X_test["D_116"].fillna(0, inplace = True)
    X_test["D_64"].fillna("U", inplace = True)
    X_test["D_68"].fillna(4, inplace = True)
    X_test["B_30"].fillna(1, inplace = True)
    X_test["B_38"].fillna(4, inplace = True)
    X_test["D_114"].fillna(0, inplace = True)
    X_test["D_117"].fillna(6, inplace = True)
    X_test["D_120"].fillna(1, inplace = True)
    X_test["D_126"].fillna(0, inplace = True)
    
    # Fitting to LabelEncoder
    D_64 = le.fit_transform(X_test["D_63"])
    D_63 = le.fit_transform(X_test["D_64"])
    
    X_test["D_64"] = D_64
    X_test["D_63"] = D_63
    

    # Changing Types 
    X_test = np.asarray(X_test)
    X_test = tf.constant(X_test, dtype = tf.float32)
    y_test_pred = model.predict(X_test)#[:, 1]
    _index.extend(_chunk["customer_ID"])
    _vals.extend(y_test_pred)
    
    print(len(_index))
# Out:
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_66"].fillna(1, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_116"].fillna(0, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_64"].fillna("U", inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_68"].fillna(4, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["B_30"].fillna(1, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["B_38"].fillna(4, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_114"].fillna(0, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_117"].fillna(6, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_120"].fillna(1, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_126"].fillna(0, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_64"] = D_64
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_63"] = D_63
# 2543/2543 [==============================] - 2s 681us/step
# 81358
#    1/2540 [..............................] - ETA: 30s
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_66"].fillna(1, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_116"].fillna(0, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_64"].fillna("U", inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_68"].fillna(4, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["B_30"].fillna(1, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["B_38"].fillna(4, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_114"].fillna(0, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_117"].fillna(6, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_120"].fillna(1, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_126"].fillna(0, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_64"] = D_64
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_63"] = D_63
# 2540/2540 [==============================] - 2s 706us/step
# 162618
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_66"].fillna(1, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_116"].fillna(0, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_64"].fillna("U", inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_68"].fillna(4, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["B_30"].fillna(1, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["B_38"].fillna(4, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_114"].fillna(0, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_117"].fillna(6, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_120"].fillna(1, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_126"].fillna(0, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_64"] = D_64
#  140/2546 [>.............................] - ETA: 1s
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_63"] = D_63
# 2546/2546 [==============================] - 2s 668us/step
# 244059
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_66"].fillna(1, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_116"].fillna(0, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_64"].fillna("U", inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_68"].fillna(4, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["B_30"].fillna(1, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["B_38"].fillna(4, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_114"].fillna(0, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_117"].fillna(6, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_120"].fillna(1, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_126"].fillna(0, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_64"] = D_64
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_63"] = D_63
# 2544/2544 [==============================] - 2s 654us/step
# 325450
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_66"].fillna(1, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_116"].fillna(0, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_64"].fillna("U", inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_68"].fillna(4, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["B_30"].fillna(1, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["B_38"].fillna(4, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_114"].fillna(0, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_117"].fillna(6, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_120"].fillna(1, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_126"].fillna(0, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_64"] = D_64
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_63"] = D_63
# 2543/2543 [==============================] - 2s 680us/step
# 406815
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_66"].fillna(1, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_116"].fillna(0, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_64"].fillna("U", inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_68"].fillna(4, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["B_30"].fillna(1, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["B_38"].fillna(4, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_114"].fillna(0, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_117"].fillna(6, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_120"].fillna(1, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_126"].fillna(0, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_64"] = D_64
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_63"] = D_63
# 2546/2546 [==============================] - 2s 632us/step
# 488260
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_66"].fillna(1, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_116"].fillna(0, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_64"].fillna("U", inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_68"].fillna(4, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["B_30"].fillna(1, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["B_38"].fillna(4, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_114"].fillna(0, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_117"].fillna(6, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_120"].fillna(1, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_126"].fillna(0, inplace = True)
#  126/2541 [>.............................] - ETA: 1s
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_64"] = D_64
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_63"] = D_63
# 2541/2541 [==============================] - 2s 710us/step
# 569555
#    1/2543 [..............................] - ETA: 29s
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_66"].fillna(1, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_116"].fillna(0, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_64"].fillna("U", inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_68"].fillna(4, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["B_30"].fillna(1, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["B_38"].fillna(4, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_114"].fillna(0, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_117"].fillna(6, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_120"].fillna(1, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_126"].fillna(0, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_64"] = D_64
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_63"] = D_63
# 2543/2543 [==============================] - 2s 660us/step
# 650904
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_66"].fillna(1, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_116"].fillna(0, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_64"].fillna("U", inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_68"].fillna(4, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["B_30"].fillna(1, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["B_38"].fillna(4, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_114"].fillna(0, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_117"].fillna(6, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_120"].fillna(1, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_126"].fillna(0, inplace = True)
#  141/2542 [>.............................] - ETA: 1s
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_64"] = D_64
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_63"] = D_63
# 2542/2542 [==============================] - 2s 728us/step
# 732217
#    1/2542 [..............................] - ETA: 31s
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_66"].fillna(1, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_116"].fillna(0, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_64"].fillna("U", inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_68"].fillna(4, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["B_30"].fillna(1, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["B_38"].fillna(4, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_114"].fillna(0, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_117"].fillna(6, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_120"].fillna(1, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_126"].fillna(0, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_64"] = D_64
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_63"] = D_63
# 2542/2542 [==============================] - 2s 631us/step
# 813543
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_66"].fillna(1, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_116"].fillna(0, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_64"].fillna("U", inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_68"].fillna(4, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["B_30"].fillna(1, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["B_38"].fillna(4, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_114"].fillna(0, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_117"].fillna(6, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_120"].fillna(1, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_126"].fillna(0, inplace = True)
#  144/2547 [>.............................] - ETA: 1s
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_64"] = D_64
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_63"] = D_63
# 2547/2547 [==============================] - 2s 649us/step
# 895040
#   1/925 [..............................] - ETA: 10s
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_66"].fillna(1, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_116"].fillna(0, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_64"].fillna("U", inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_68"].fillna(4, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["B_30"].fillna(1, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["B_38"].fillna(4, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_114"].fillna(0, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_117"].fillna(6, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_120"].fillna(1, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_126"].fillna(0, inplace = True)
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_64"] = D_64
# /var/folders/p_/j8lh2l8d3r3dwh95sx4bxlt40000gn/T/ipykernel_2460/642940333.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["D_63"] = D_63
# 925/925 [==============================] - 1s 666us/step
# 924631

# %%
res_df = pd.DataFrame(
    {"customer_ID": _index, "prediction": np.squeeze(_vals)}
).groupby("customer_ID")["prediction"].mean().reset_index()

# %%
res_df.isna().sum()
# Out:
# customer_ID    0
# prediction     0
# dtype: int64

# %%
res_df.head()
# Out:
#                                          customer_ID  prediction
# 0  00000469ba478561f23a92a868bd366de6f6527a684c9a...    0.395500
# 1  00001bf2e77ff879fab36aa4fac689b9ba411dae63ae39...    0.092948
# 2  0000210045da4f81e5f122c6bde5c2a617d03eef67f82c...    0.243021
# 3  00003b41e58ede33b8daf61ab56d9952f17c9ad1c3976c...    0.226076
# 4  00004b22eaeeeb0ec976890c1d9bfc14fd9427e98c4ee9...    0.660890

# %%
res_df.to_csv("tensorflow_predictions_submission_with_categorical_data.csv", index = False)
